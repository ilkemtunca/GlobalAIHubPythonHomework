# %%
x = input('Name: ')
y = input('Surname: ')
n = int(input('Date Of Birth(just year): '))

age = int(input('Age: '))

if age < 18:
    print('You cant go out because its too dangerous!')
elif age >= 18:
    print('You can go out to the street.')
# Out:
# Name: İLKEM
# Surname: TUNCA
# Date Of Birth(just year): 2000
# Age: 20
# You can go out to the street.
