# %%
x = input(f'Please Enter A number: ')
print(type(x))
# Out:
# Please Enter A number: 5
# <class 'str'>

# %%
x = int(input(f'Please Enter A Number: '))
print(type(x))
# Out:
# Please Enter A Number: 13
# <class 'int'>

# %%
x = float(input(f'Please Enter A Number: '))
print(type(x))
# Out:
# Please Enter A Number: 67.9
# <class 'float'>

# %%
x = int(input(f'Please Enter A Number: '))
print(type(x))
# Out:
# Please Enter A Number: 4356
# <class 'int'>

# %%
x = float(input(f'Please Enter A Number: '))
print(type(x))
# Out:
# Please Enter A Number: 7.4
# <class 'float'>
